# %% [markdown]
# # Pandas

# %%
import pandas as pd

# %%
import numpy as np

# %%
import csv

# %%
datos= pd.read_csv("athlete_events.csv")

# %%
datos
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %%
# para tomar la columna id como indice lo hacemos de la siguiente manera...
datos= pd.read_csv("athlete_events.csv", index_col=0)

# %%
datos
# Out:
#                             Name Sex   Age  Height  Weight            Team  \
# ID
# 1                      A Dijiang   M  24.0   180.0    80.0           China
# 2                       A Lamusi   M  23.0   170.0    60.0           China
# 3            Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 4           Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 5       Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
# ...                          ...  ..   ...     ...     ...             ...
# 135569                Andrzej ya   M  29.0   179.0    89.0        Poland-1
# 135570                  Piotr ya   M  27.0   176.0    59.0          Poland
# 135570                  Piotr ya   M  27.0   176.0    59.0          Poland
# 135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0          Poland
# 135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0          Poland
#
# ...

# %%
datos= pd.read_csv("athlete_events.csv") # lo dej normal pq tengo ids repetidos en varias filas

# %%
datos
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %%
# para ver los datos de un campo concreto..pongo unique para que no se repitan los datos
datos["Name"].unique()
# Out:
# array(['A Dijiang', 'A Lamusi', 'Gunnar Nielsen Aaby', ..., 'Andrzej ya',
#        'Piotr ya', 'Tomasz Ireneusz ya'], dtype=object)

# %%
datos["Sex"].unique()
# Out:
# array(['M', 'F'], dtype=object)

# %%
datos["Name"].tolist().unique()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3196/2990878864.py in <module>
# ----> 1 datos["Name"].tolist().unique()
#
# AttributeError: 'list' object has no attribute 'unique'

# %%
datos["Name"].unique().tolist()
# Out:
# ['A Dijiang',
#  'A Lamusi',
#  'Gunnar Nielsen Aaby',
#  'Edgar Lindenau Aabye',
#  'Christine Jacoba Aaftink',
#  'Per Knut Aaland',
#  'John Aalberg',
#  'Cornelia "Cor" Aalten (-Strannood)',
#  'Antti Sami Aalto',
#  'Einar Ferdinand "Einari" Aalto',
#  'Jorma Ilmari Aalto',
#  'Jyri Tapani Aalto',
#  'Minna Maarit Aalto',
#  'Pirjo Hannele Aalto (Mattila-)',
#  'Arvo Ossian Aaltonen',
#  'Juhamatti Tapio Aaltonen',
#  'Paavo Johannes Aaltonen',
#  'Timo Antero Aaltonen',
#  'Win Valdemar Aaltonen',
#  'Kjetil Andr Aamodt',
#  'Ragnhild Margrethe Aamodt',
#  'Andreea Aanei',
#  'Fritz Aanes',
#  'Nils Egil Aaness',
#  'Alf Lied Aanning',
#  'Agnes Erika Aanonsen (-Eyde)',
#  'Johan Aantjes',
#  'Jan-Erik Aarberg',
#  'Willemien Aardenburg',
#  'Pepijn Aardewijn',
#  'Evald rma (rman-)',
#  'Olav Augunson Aarnes',
#  'Mika Lauri Aarnikka',
#  'Jamale (Djamel-) Aarrass (Ahrass-)',
#  'Dagfinn Sverre Aarskog',
#  'Stefan Remco Aartsen',
#  'Ann Kristin Aarnes',
#  'Karl Jan Aas',
# ...

# %%
mayor=datos[datos["Age"]==datos["Age"].max()]

# %%
mayor
# Out:
#             ID                    Name Sex   Age  Height  Weight  \
# 257054  128719  John Quincy Adams Ward   M  97.0     NaN     NaN
#
#                  Team  NOC        Games  Year  Season       City  \
# 257054  United States  USA  1928 Summer  1928  Summer  Amsterdam
#
#                    Sport                                        Event Medal
# 257054  Art Competitions  Art Competitions Mixed Sculpturing, Statues   NaN

# %%
mayor[datos["Medal"].notna()]
# Out:
# C:\Users\p-aangel\AppData\Local\Temp/ipykernel_3196/2031075877.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   mayor[datos["Medal"].notna()]
# Empty DataFrame
# Columns: [ID, Name, Sex, Age, Height, Weight, Team, NOC, Games, Year, Season, City, Sport, Event, Medal]
# Index: []

# %%
datos=datos[datos["Medal"]=="Gold"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3196/291926309.py in <module>
# ----> 1 datos=datos[datos["Medal"]=="Gold"]
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     940
#     941         elif key_is_scalar:
# --> 942             return self._get_value(key)
#     943
#     944         if is_hashable(key):
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in _get_value(self, label, takeable)
#    1049
#    1050         # Similar to Index.get_value, but we do not fall back to positional
# -> 1051         loc = self.index.get_loc(label)
#    1052         return self.index._get_values_for_loc(self, loc, label)
#    1053
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\range.py in get_loc(self, key, method, tolerance)
#     386                 except ValueError as err:
# ...

# %%
datos[datos["Age"]==datos["Age"].min()]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3196/2750561388.py in <module>
# ----> 1 datos[datos["Age"]==datos["Age"].min()]
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     940
#     941         elif key_is_scalar:
# --> 942             return self._get_value(key)
#     943
#     944         if is_hashable(key):
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in _get_value(self, label, takeable)
#    1049
#    1050         # Similar to Index.get_value, but we do not fall back to positional
# -> 1051         loc = self.index.get_loc(label)
#    1052         return self.index._get_values_for_loc(self, loc, label)
#    1053
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\range.py in get_loc(self, key, method, tolerance)
#     386                 except ValueError as err:
# ...
